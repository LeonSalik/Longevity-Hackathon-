# %% [markdown]
# ## This notebook is for testing the LLM we use to tabulate data for MASH-COM

# %% [markdown]
# ### Now that the data has been retreaved we have to check that the model didn't halucinate them.
#
# We do this by using an audit function.

# %% [markdown]
# ### Data is now checked, time to tabulate it.

# %% [markdown]
# ### Now that the LLM structure is built we have to move data into it.
#
# Medical data is sensitive and difficult to find and hard to use without ethical conserns. Our solution to this problem is using a few random clinical notes, that have been cleared for use, to generate clinical notes to train our model. Obviously not ideal, but other than training on real notes, its the best we've got.
